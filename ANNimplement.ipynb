# %%
#churn modelling datasetb - simple binary classification problem

# %% [markdown]
# ### Based on the given data identify if the person is going to leave the bank or not

# %% [markdown]
# ### Steps in solving any problem using machine learning
# #### 1. perform feature engineering and identify number of features
# #### 2. Text preprocessing and cleaning
# #### 3. build an artificial neural network
# #### 4. optimize the network using diff algorithms
# #### 5. deploy the web app on streamlit

# %% [markdown]
# ### Setting up project environment
# conda -p venv python=3.11 -y
#
# requirements -> tensorflow
# pandas
# numpy
# scikit-learn
# tensorboard
# matplotlib
# streamlit
#
# conda activate venv/
#
# pip install -r requirements.txt
#
# #### install ipykernel to attach and run jupyter notebook in vscode
# pip install ipykernel
